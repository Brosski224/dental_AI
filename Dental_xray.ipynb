# %%
from google.colab import drive

# %%
# !pip install ultralytics opencv-python numpy matplotlib
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.3/112.6 GB disk)

# %%
from ultralytics import YOLO

# Load YOLO model
model = YOLO('yolov8n.pt')

# Train with CLAHE-augmented images
model.train(
    data="/content/drive/MyDrive/Dental OPG XRAY Dataset-20250306T161920Z-001/Dental OPG XRAY Dataset/Dental OPG (Object Detection)/Augmented Dataset/data.yaml",
    epochs=50,                # Increase epochs for better learning
    imgsz=640,                # Image size
    batch=16,                 # Batch size
    patience=5,               # Early stopping if no improvement in 5 epochs
    optimizer='AdamW',        # Better weight decay and generalization
    dropout=0.5,              # Reduces overfitting
    weight_decay=0.0005,      # Regularization
    device="CUDA"             # Use GPU (CUDA 12.4 in Colab)
)
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Dental OPG XRAY Dataset-20250306T161920Z-001/Dental OPG XRAY Dataset/Dental OPG (Object Detection)/Augmented Dataset/valid/labels.cache... 23 images, 0 backgrounds, 0 corrupt: 100%|██████████| 23/23 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.75it/s]
#                    all         23        115      0.788      0.377      0.471      0.254
#          Healthy Teeth          8         14      0.706        0.5      0.549      0.356
#        Fractured Teeth          3          4          1          0      0.144       0.07
#                 Caries          7         18      0.951          1      0.995      0.516
# ...

# %%
results = model.predict("/content/drive/MyDrive/Dental OPG XRAY Dataset-20250306T161920Z-001/Dental OPG XRAY Dataset/Dental OPG (Classification)/Caries/112.jpg")
# Access the first Results object in the list (assuming there is at least one)
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/Dental OPG XRAY Dataset-20250306T161920Z-001/Dental OPG XRAY Dataset/Dental OPG (Classification)/Caries/112.jpg: 320x640 2 Cariess, 3 Impacted Teeths, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=1142x529>

# %%
import torch
torch.save(model.state_dict(), "weights.pt")  # Replace with your desired path and filename

# %%
from ultralytics import YOLO

# %%
model.export(format="torchscript", save_dir='.')  # Added save_dir='.' to save in the current path
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train4/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (5.9 MB)
#
# TorchScript: starting export with torch 2.5.1+cu121...
# TorchScript: export success ✅ 2.6s, saved as 'runs/detect/train4/weights/best.torchscript' (11.9 MB)
#
# Export complete (3.2s)
# Results saved to /content/runs/detect/train4/weights
# Predict:         yolo predict task=detect model=runs/detect/train4/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train4/weights/best.torchscript imgsz=640 data=/content/drive/MyDrive/Dental OPG XRAY Dataset-20250306T161920Z-001/Dental OPG XRAY Dataset/Dental OPG (Object Detection)/Augmented Dataset/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train4/weights/best.torchscript'
